# %% [markdown]
# # Install

# %%
# !pip3 install hydra-core

# %%
# !pip3 install transformers

# %%
# !pip install --upgrade accelerate

# %%
# !pip3 install datasets

# %%
# !pip3 install wandb

# %%
# !pip3 install pshmodule

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Run

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/business_model/t5_selling/')

# %%
# !python3 train.py

# %% [markdown]
# # Predict

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/business_model/t5_selling/')

# %%
# !python3 predict.py
# Out:
# 2023-07-07 09:42:43.375237: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/MyDrive/Advertising_By_Personality/src/business_model/t5_selling/predict.py:13: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="./", config_name="config")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# extension : .xlsx
# Loaded 12 records from /content/drive/MyDrive/Advertising_By_Personality/data/reports/test.xlsx
#    no  ... T5 문체변환
# 0 NaN  ...     NaN
# 1 NaN  ...     NaN
# 2 NaN  ...     NaN
# 3 NaN  ...     NaN
# 4 NaN  ...     NaN
#
# [5 rows x 4 columns]
# 0번째 행
# 원문 : <input>우리집 앞에 치킨집 '또래오래', '오픈기념 할인행사', 두 마리를 9,900원에, IMF가격으로\\nan
# 모델 답변 :  앞에 치킨집이 생겼어요🍞
#
# 요즘 핫한 [또래오래]가 생겼어요😊 오픈 기념 할인가로 두 마리를 9,9OO원에 살 수 있는 찬스! 치킨 맛은 그대로! 가격은 그대로!🍴
# ----------------------------------------------------------------------------------------------------
# 1번째 행
# 원문 : <input>학습지 무료체험만 해도 사은품 증정\\nan
# 모델 답변 : ud83d 무료체험 신청하고 사은품 받아가세요
#
# 학습지 무료체험 신청 시 무료 체험 시 학습지 무료 체험 혜택 증정
#
# 학습지 무료 체험 신청 시 사은품🎁까지 다 드림! 이거이거 안 할 이유가 없쥬~?👀
# ----------------------------------------------------------------------------------------------------
# 2번째 행
# 원문 : <input>좋은 침대, 바른 침구, 잠이 보약\\[세사리빙]
# 모델 답변 :  매트리스가 보약👊
#
# [세사리빙]: 좋은 침대, 바른 침구, 잠이 보약✨ 이 모든 혜택은 고객님을 위해 준비한 선물💖 좋은 침대, 바른 침구, 잠이 보약! 지금 바로 보러 가시죠!👉
# ----------------------------------------------------------------------------------------------------
# 3번째 행
# 원문 : <input>쿠쿠 인스퓨어 100℃끓인물정
# 수기\\백도로 끓여서 깊은 풍미와 깨끗함을 자랑합니다
# 모델 답변 : 수 있다! 쿠쿠 인스퓨어 100°C 끓이기🙋
#
# [쿠쿠 인스퓨어] 백도로 찐 다음 찐 맛을 자랑하는 [쿠쿠 인스퓨어] 1OO°C 끓인물정 수! 바로 받아가세요!👉
# ----------------------------------------------------------------------------------------------------
# 4번째 행
# 원문 : <input>설 연휴 기념 전원 캐시 선물\\2월 특급 신작 지금 확인
# 모델 답변 :  선물 받아가세요😋
#
# CJ ONE 2월 특급 신작 확인하려면?
#
# 1OO명 전원 캐시💸, 설 연휴 종료 후 종료 예정
#
# 1OO명 전원 캐시💰 지급! 2월 신작 바로 확인하러 GO!▶
# ----------------------------------------------------------------------------------------------------
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /usr/local/lib/python3.10/dist-packages/hydra/core/utils.py:186 in run_job   │
# │                                                                              │
# │   183 │   │   with env_override(hydra_cfg.hydra.job.env_set):                │
# │   184 │   │   │   callbacks.on_job_start(config=config, task_function=task_f │
# │   185 │   │   │   try:                                                       │
# │ ❱ 186 │   │   │   │   ret.return_value = task_function(task_cfg)             │
# │   187 │   │   │   │   ret.status = JobStatus.COMPLETED                       │
# │   188 │   │   │   except Exception as e:                                     │
# │   189 │   │   │   │   ret.return_value = e                                   │
# │                                                                              │
# │ /content/drive/MyDrive/Advertising_By_Personality/src/business_model/t5_sell │
# │ ing/predict.py:55 in main                                                    │
# │                                                                              │
# │   52 │   │   sample = {k: torch.tensor([v]).to(device) for k, v in encoded.i │
# │   53 │   │                                                                   │
# │   54 │   │   with torch.no_grad():                                           │
# │ ❱ 55 │   │   │   pred = model.generate(                                      │
# │   56 │   │   │   │   **sample,                                               │
# │   57 │   │   │   │   temperature=0.7,                                        │
# │   58 │   │   │   │   do_sample=True,                                         │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115 in    │
# │ decorate_context                                                             │
# │                                                                              │
# │   112 │   @functools.wraps(func)                                             │
# │   113 │   def decorate_context(*args, **kwargs):                             │
# │   114 │   │   with ctx_factory():                                            │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                               │
# │   116 │                                                                      │
# │   117 │   return decorate_context                                            │
# │   118                                                                        │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:157 │
# │ 2 in generate                                                                │
# │                                                                              │
# │   1569 │   │   │   )                                                         │
# │   1570 │   │   │                                                             │
# │   1571 │   │   │   # 13. run sample                                          │
# │ ❱ 1572 │   │   │   return self.sample(                                       │
# │   1573 │   │   │   │   input_ids,                                            │
# │   1574 │   │   │   │   logits_processor=logits_processor,                    │
# │   1575 │   │   │   │   logits_warper=logits_warper,                          │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:261 │
# │ 9 in sample                                                                  │
# │                                                                              │
# │   2616 │   │   │   model_inputs = self.prepare_inputs_for_generation(input_i │
# │   2617 │   │   │                                                             │
# │   2618 │   │   │   # forward pass to get next token                          │
# │ ❱ 2619 │   │   │   outputs = self(                                           │
# │   2620 │   │   │   │   **model_inputs,                                       │
# │   2621 │   │   │   │   return_dict=True,                                     │
# │   2622 │   │   │   │   output_attentions=output_attentions,                  │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501 in   │
# │ _call_impl                                                                   │
# │                                                                              │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or s │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hoo │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                      │
# │   1502 │   │   # Do not call functions when jit is used                      │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []         │
# │   1504 │   │   backward_pre_hooks = []                                       │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.p │
# │ y:1720 in forward                                                            │
# │                                                                              │
# │   1717 │   │   │   │   decoder_attention_mask = decoder_attention_mask.to(se │
# │   1718 │   │                                                                 │
# │   1719 │   │   # Decode                                                      │
# │ ❱ 1720 │   │   decoder_outputs = self.decoder(                               │
# │   1721 │   │   │   input_ids=decoder_input_ids,                              │
# │   1722 │   │   │   attention_mask=decoder_attention_mask,                    │
# │   1723 │   │   │   inputs_embeds=decoder_inputs_embeds,                      │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501 in   │
# │ _call_impl                                                                   │
# │                                                                              │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or s │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hoo │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                      │
# │   1502 │   │   # Do not call functions when jit is used                      │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []         │
# │   1504 │   │   backward_pre_hooks = []                                       │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.p │
# │ y:1090 in forward                                                            │
# │                                                                              │
# │   1087 │   │   │   │   │   None,  # past_key_value is always None with gradi │
# │   1088 │   │   │   │   )                                                     │
# │   1089 │   │   │   else:                                                     │
# │ ❱ 1090 │   │   │   │   layer_outputs = layer_module(                         │
# │   1091 │   │   │   │   │   hidden_states,                                    │
# │   1092 │   │   │   │   │   attention_mask=extended_attention_mask,           │
# │   1093 │   │   │   │   │   position_bias=position_bias,                      │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501 in   │
# │ _call_impl                                                                   │
# │                                                                              │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or s │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hoo │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                      │
# │   1502 │   │   # Do not call functions when jit is used                      │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []         │
# │   1504 │   │   backward_pre_hooks = []                                       │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.p │
# │ y:723 in forward                                                             │
# │                                                                              │
# │    720 │   │   │   else:                                                     │
# │    721 │   │   │   │   query_length = None                                   │
# │    722 │   │   │                                                             │
# │ ❱  723 │   │   │   cross_attention_outputs = self.layer[1](                  │
# │    724 │   │   │   │   hidden_states,                                        │
# │    725 │   │   │   │   key_value_states=encoder_hidden_states,               │
# │    726 │   │   │   │   attention_mask=encoder_attention_mask,                │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501 in   │
# │ _call_impl                                                                   │
# │                                                                              │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or s │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hoo │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                      │
# │   1502 │   │   # Do not call functions when jit is used                      │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []         │
# │   1504 │   │   backward_pre_hooks = []                                       │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.p │
# │ y:634 in forward                                                             │
# │                                                                              │
# │    631 │   │   output_attentions=False,                                      │
# │    632 │   ):                                                                │
# │    633 │   │   normed_hidden_states = self.layer_norm(hidden_states)         │
# │ ❱  634 │   │   attention_output = self.EncDecAttention(                      │
# │    635 │   │   │   normed_hidden_states,                                     │
# │    636 │   │   │   mask=attention_mask,                                      │
# │    637 │   │   │   key_value_states=key_value_states,                        │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501 in   │
# │ _call_impl                                                                   │
# │                                                                              │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or s │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hoo │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                      │
# │   1502 │   │   # Do not call functions when jit is used                      │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []         │
# │   1504 │   │   backward_pre_hooks = []                                       │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.p │
# │ y:560 in forward                                                             │
# │                                                                              │
# │    557 │   │   │   position_bias_masked = position_bias                      │
# │    558 │   │                                                                 │
# │    559 │   │   scores += position_bias_masked                                │
# │ ❱  560 │   │   attn_weights = nn.functional.softmax(scores.float(), dim=-1). │
# │    561 │   │   │   scores                                                    │
# │    562 │   │   )  # (batch_size, n_heads, seq_length, key_length)            │
# │    563 │   │   attn_weights = nn.functional.dropout(                         │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/drive/MyDrive/Advertising_By_Personality/src/business_model/t5_sell │
# │ ing/predict.py:89 in <module>                                                │
# │                                                                              │
# │   86                                                                         │
# │   87                                                                         │
# │   88 if __name__ == "__main__":                                              │
# │ ❱ 89 │   main()                                                              │
# │   90                                                                         │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/hydra/main.py:94 in decorated_main   │
# │                                                                              │
# │    91 │   │   │   │   else:                                                  │
# │    92 │   │   │   │   │   # no return value from run_hydra() as it may somet │
# │    93 │   │   │   │   │   # multiple times (--multirun)                      │
# │ ❱  94 │   │   │   │   │   _run_hydra(                                        │
# │    95 │   │   │   │   │   │   args=args,                                     │
# │    96 │   │   │   │   │   │   args_parser=args_parser,                       │
# │    97 │   │   │   │   │   │   task_function=task_function,                   │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/hydra/_internal/utils.py:394 in      │
# │ _run_hydra                                                                   │
# │                                                                              │
# │   391 │   │                                                                  │
# │   392 │   │   if args.run or args.multirun:                                  │
# │   393 │   │   │   run_mode = hydra.get_mode(config_name=config_name, overrid │
# │ ❱ 394 │   │   │   _run_app(                                                  │
# │   395 │   │   │   │   run=args.run,                                          │
# │   396 │   │   │   │   multirun=args.multirun,                                │
# │   397 │   │   │   │   mode=run_mode,                                         │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/hydra/_internal/utils.py:457 in      │
# │ _run_app                                                                     │
# │                                                                              │
# │   454 │   │   │   overrides.extend(["hydra.mode=MULTIRUN"])                  │
# │   455 │                                                                      │
# │   456 │   if mode == RunMode.RUN:                                            │
# │ ❱ 457 │   │   run_and_report(                                                │
# │   458 │   │   │   lambda: hydra.run(                                         │
# │   459 │   │   │   │   config_name=config_name,                               │
# │   460 │   │   │   │   task_function=task_function,                           │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/hydra/_internal/utils.py:220 in      │
# │ run_and_report                                                               │
# │                                                                              │
# │   217                                                                        │
# │   218 def run_and_report(func: Any) -> Any:                                  │
# │   219 │   try:                                                               │
# │ ❱ 220 │   │   return func()                                                  │
# │   221 │   except Exception as ex:                                            │
# │   222 │   │   if _is_env_set("HYDRA_FULL_ERROR") or is_under_debugger():     │
# │   223 │   │   │   raise ex                                                   │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/hydra/_internal/utils.py:458 in      │
# │ <lambda>                                                                     │
# │                                                                              │
# │   455 │                                                                      │
# │   456 │   if mode == RunMode.RUN:                                            │
# │   457 │   │   run_and_report(                                                │
# │ ❱ 458 │   │   │   lambda: hydra.run(                                         │
# │   459 │   │   │   │   config_name=config_name,                               │
# │   460 │   │   │   │   task_function=task_function,                           │
# │   461 │   │   │   │   overrides=overrides,                                   │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119 in run  │
# │                                                                              │
# │   116 │   │   callbacks = Callbacks(cfg)                                     │
# │   117 │   │   callbacks.on_run_start(config=cfg, config_name=config_name)    │
# │   118 │   │                                                                  │
# │ ❱ 119 │   │   ret = run_job(                                                 │
# │   120 │   │   │   hydra_context=HydraContext(                                │
# │   121 │   │   │   │   config_loader=self.config_loader, callbacks=callbacks  │
# │   122 │   │   │   ),                                                         │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/hydra/core/utils.py:202 in run_job   │
# │                                                                              │
# │   199 │   finally:                                                           │
# │   200 │   │   HydraConfig.instance().cfg = orig_hydra_cfg                    │
# │   201 │   │   if _chdir:                                                     │
# │ ❱ 202 │   │   │   os.chdir(old_cwd)                                          │
# │   203                                                                        │
# │   204                                                                        │
# │   205 def get_valid_filename(s: str) -> str:                                 │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
# ^C
