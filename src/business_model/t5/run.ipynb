# %% [markdown]
# # Install

# %%
# !pip3 install hydra-core

# %%
# !pip3 install transformers

# %%
# !pip install --upgrade accelerate

# %%
# !pip3 install datasets

# %%
# !pip3 install wandb

# %%
# !pip3 install pshmodule

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Run

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/business_model/t5/')

# %%
# !python3 train.py
# Out:
# 2023-06-04 09:26:55.911651: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/MyDrive/Advertising_By_Personality/src/business_model/t5/train.py:16: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="./", config_name="config")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 100% 2/2 [00:00<00:00, 545.78it/s]
# wandb: Currently logged in as: psh_pat (textnet). Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# # Predict

# %%
# !ls /content/drive/MyDrive/Advertising_By_Personality/outputs/model/t5
# Out:
# checkpoint-4000  lr5e-4

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/business_model/t5/')

# %%
# !python3 predict.py
# Out:
# 2023-06-05 01:41:29.004463: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/MyDrive/Advertising_By_Personality/src/business_model/t5/predict.py:12: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="./", config_name="config")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# NT 성향 문구 : 도시락을 구매한 고객✔️500원 할인!
# NF 성향 문구 : 없음
# 마케팅 주체 : GS25
# 마케팅 대상 : 도시락을 구매한 고객
# 혜택 지급 조건 : 도시락 구입 후 QR Code 인증
# 혜택 : 금액 할인
# 할인 수치 : 500원
# 프로모션 품목 : 코카콜라 320ml
# 프로모션 장소 : 전국 GS25
# 이벤트 기간 : 5.11~5.19
# 요일 정보 : 없음
# 시즌 정보 : 여름 한정
# 소구점 : 코카콜라 할인
# 모델 답변 : 쿠폰 도착👀
# ...
