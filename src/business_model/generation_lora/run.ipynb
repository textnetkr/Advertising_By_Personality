# %% [markdown]
# # Install

# %%
# !pip3 install hydra-core

# %%
# !pip3 install transformers

# %%
# !pip3 install datasets

# %%
# !pip3 install wandb

# %%
# !pip3 install pshmodule

# %%
# !pip3 install -q bitsandbytes datasets accelerate loralib
# !pip3 install -q git+https://github.com/huggingface/transformers.git@main git+https://github.com/huggingface/peft.git
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 28.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#   Building wheel for peft (pyproject.toml) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Run

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/business_model/generation_lora')

# %%
# !python3 train.py
# Out:
# 2023-05-10 06:48:27.931397: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: /usr/lib64-nvidia did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.28.0.1'), PosixPath('8013'), PosixPath('http')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-a100-s-1pzitau1yn1ps --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true'), PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//ipykernel.pylab.backend_inline')}
#   warn(msg)
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching in backup paths...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: Found duplicate ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] files: {PosixPath('/usr/local/cuda/lib64/libcudart.so'), PosixPath('/usr/local/cuda/lib64/libcudart.so.11.0')}.. We'll flip a coin and try one of these, in order to fail forward.
# Either way, this might cause trouble in the future:
# If you get `CUDA error: invalid device function` errors, the above might be the cause and the solution is to make sure only one ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] in the paths that we search based on your env.
#   warn(msg)
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.0
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /content/drive/MyDrive/Advertising_By_Personality/src/business_model/generation_lora/train.py:18: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="./", config_name="config")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Downloading (…)okenizer_config.json: 100% 210/210 [00:00<00:00, 1.29MB/s]
# Downloading (…)/main/tokenizer.json: 100% 1.65M/1.65M [00:00<00:00, 1.66MB/s]
# Downloading (…)cial_tokens_map.json: 100% 185/185 [00:00<00:00, 1.12MB/s]
# Overriding torch_dtype=None with `torch_dtype=torch.float16` due to requirements of `bitsandbytes` to enable model loading in mixed int8. Either pass torch_dtype=torch.float16 or don't pass this argument at all to remove this warning.
# Downloading (…)lve/main/config.json: 100% 663/663 [00:00<00:00, 2.77MB/s]
# Downloading (…)model.bin.index.json: 100% 36.8k/36.8k [00:00<00:00, 134MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0% 0.00/10.0G [00:00<?, ?B/s]
# Downloading (…)l-00001-of-00002.bin:   0% 21.0M/10.0G [00:00<00:55, 179MB/s]
# Downloading (…)l-00001-of-00002.bin:   1% 73.4M/10.0G [00:00<00:29, 336MB/s]
# Downloading (…)l-00001-of-00002.bin:   1% 126M/10.0G [00:00<00:24, 404MB/s]
# Downloading (…)l-00001-of-00002.bin:   2% 178M/10.0G [00:00<00:22, 438MB/s]
# Downloading (…)l-00001-of-00002.bin:   2% 231M/10.0G [00:00<00:21, 458MB/s]
# Downloading (…)l-00001-of-00002.bin:   3% 283M/10.0G [00:00<00:20, 468MB/s]
# Downloading (…)l-00001-of-00002.bin:   3% 336M/10.0G [00:00<00:20, 476MB/s]
# Downloading (…)l-00001-of-00002.bin:   4% 388M/10.0G [00:00<00:19, 482MB/s]
# Downloading (…)l-00001-of-00002.bin:   4% 440M/10.0G [00:00<00:19, 487MB/s]
# Downloading (…)l-00001-of-00002.bin:   5% 493M/10.0G [00:01<00:19, 486MB/s]
# Downloading (…)l-00001-of-00002.bin:   5% 545M/10.0G [00:01<00:19, 486MB/s]
# Downloading (…)l-00001-of-00002.bin:   6% 598M/10.0G [00:01<00:19, 487MB/s]
# Downloading (…)l-00001-of-00002.bin:   6% 650M/10.0G [00:01<00:19, 489MB/s]
# Downloading (…)l-00001-of-00002.bin:   7% 703M/10.0G [00:01<00:18, 493MB/s]
# Downloading (…)l-00001-of-00002.bin:   8% 755M/10.0G [00:01<00:18, 493MB/s]
# Downloading (…)l-00001-of-00002.bin:   8% 807M/10.0G [00:01<00:18, 493MB/s]
# Downloading (…)l-00001-of-00002.bin:   9% 860M/10.0G [00:01<00:18, 494MB/s]
# Downloading (…)l-00001-of-00002.bin:   9% 912M/10.0G [00:01<00:18, 488MB/s]
# Downloading (…)l-00001-of-00002.bin:  10% 965M/10.0G [00:02<00:18, 483MB/s]
# Downloading (…)l-00001-of-00002.bin:  10% 1.02G/10.0G [00:02<00:18, 483MB/s]
# Downloading (…)l-00001-of-00002.bin:  11% 1.07G/10.0G [00:02<00:18, 477MB/s]
# Downloading (…)l-00001-of-00002.bin:  11% 1.12G/10.0G [00:02<00:19, 467MB/s]
# Downloading (…)l-00001-of-00002.bin:  12% 1.17G/10.0G [00:02<00:19, 458MB/s]
# Downloading (…)l-00001-of-00002.bin:  12% 1.23G/10.0G [00:02<00:19, 457MB/s]
# Downloading (…)l-00001-of-00002.bin:  13% 1.28G/10.0G [00:02<00:19, 451MB/s]
# Downloading (…)l-00001-of-00002.bin:  13% 1.33G/10.0G [00:02<00:20, 426MB/s]
# Downloading (…)l-00001-of-00002.bin:  14% 1.38G/10.0G [00:03<00:21, 409MB/s]
# Downloading (…)l-00001-of-00002.bin:  14% 1.43G/10.0G [00:03<00:21, 404MB/s]
# Downloading (…)l-00001-of-00002.bin:  15% 1.47G/10.0G [00:03<00:21, 397MB/s]
# Downloading (…)l-00001-of-00002.bin:  15% 1.51G/10.0G [00:03<00:21, 397MB/s]
# Downloading (…)l-00001-of-00002.bin:  15% 1.55G/10.0G [00:03<00:21, 393MB/s]
# Downloading (…)l-00001-of-00002.bin:  16% 1.59G/10.0G [00:03<00:21, 394MB/s]
# Downloading (…)l-00001-of-00002.bin:  16% 1.64G/10.0G [00:03<00:21, 392MB/s]
# Downloading (…)l-00001-of-00002.bin:  17% 1.68G/10.0G [00:03<00:21, 391MB/s]
# Downloading (…)l-00001-of-00002.bin:  17% 1.72G/10.0G [00:03<00:21, 387MB/s]
# Downloading (…)l-00001-of-00002.bin:  18% 1.76G/10.0G [00:03<00:21, 390MB/s]
# Downloading (…)l-00001-of-00002.bin:  18% 1.80G/10.0G [00:04<00:20, 393MB/s]
# Downloading (…)l-00001-of-00002.bin:  18% 1.85G/10.0G [00:04<00:20, 399MB/s]
# Downloading (…)l-00001-of-00002.bin:  19% 1.89G/10.0G [00:04<00:20, 401MB/s]
# Downloading (…)l-00001-of-00002.bin:  19% 1.93G/10.0G [00:04<00:20, 399MB/s]
# Downloading (…)l-00001-of-00002.bin:  20% 1.97G/10.0G [00:04<00:19, 403MB/s]
# Downloading (…)l-00001-of-00002.bin:  20% 2.01G/10.0G [00:04<00:19, 404MB/s]
# Downloading (…)l-00001-of-00002.bin:  98% 9.87G/10.0G [00:26<00:00, 296MB/s]
# Downloading (…)l-00001-of-00002.bin:  99% 9.90G/10.0G [00:26<00:00, 288MB/s]
# Downloading (…)l-00001-of-00002.bin:  99% 9.93G/10.0G [00:27<00:00, 285MB/s]
# Downloading (…)l-00001-of-00002.bin:  99% 9.96G/10.0G [00:27<00:00, 276MB/s]
# Downloading (…)l-00001-of-00002.bin: 100% 10.0G/10.0G [00:27<00:00, 366MB/s]
# Downloading shards:  50% 1/2 [00:27<00:27, 27.98s/it]
# Downloading (…)l-00002-of-00002.bin:   0% 0.00/1.87G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   3% 62.9M/1.87G [00:00<00:03, 531MB/s]
# Downloading (…)l-00002-of-00002.bin:   7% 126M/1.87G [00:00<00:03, 500MB/s]
# Downloading (…)l-00002-of-00002.bin:  10% 178M/1.87G [00:00<00:03, 506MB/s]
# Downloading (…)l-00002-of-00002.bin:  13% 241M/1.87G [00:00<00:03, 519MB/s]
# Downloading (…)l-00002-of-00002.bin:  16% 294M/1.87G [00:00<00:03, 499MB/s]
# Downloading (…)l-00002-of-00002.bin:  19% 346M/1.87G [00:00<00:03, 499MB/s]
# Downloading (…)l-00002-of-00002.bin:  22% 409M/1.87G [00:00<00:02, 508MB/s]
# Downloading (…)l-00002-of-00002.bin:  25% 472M/1.87G [00:00<00:02, 522MB/s]
# Downloading (…)l-00002-of-00002.bin:  29% 535M/1.87G [00:01<00:02, 537MB/s]
# Downloading (…)l-00002-of-00002.bin:  32% 598M/1.87G [00:01<00:02, 536MB/s]
# Downloading (…)l-00002-of-00002.bin:  35% 661M/1.87G [00:01<00:02, 536MB/s]
# Downloading (…)l-00002-of-00002.bin:  39% 724M/1.87G [00:01<00:02, 529MB/s]
# Downloading (…)l-00002-of-00002.bin:  42% 786M/1.87G [00:01<00:02, 526MB/s]
# Downloading (…)l-00002-of-00002.bin:  45% 849M/1.87G [00:01<00:01, 527MB/s]
# Downloading (…)l-00002-of-00002.bin:  49% 912M/1.87G [00:01<00:01, 514MB/s]
# Downloading (…)l-00002-of-00002.bin:  52% 965M/1.87G [00:01<00:01, 459MB/s]
# Downloading (…)l-00002-of-00002.bin:  54% 1.02G/1.87G [00:02<00:02, 416MB/s]
# Downloading (…)l-00002-of-00002.bin:  57% 1.07G/1.87G [00:02<00:02, 393MB/s]
# Downloading (…)l-00002-of-00002.bin:  59% 1.11G/1.87G [00:02<00:02, 376MB/s]
# Downloading (…)l-00002-of-00002.bin:  62% 1.15G/1.87G [00:02<00:01, 365MB/s]
# Downloading (…)l-00002-of-00002.bin:  64% 1.20G/1.87G [00:02<00:01, 371MB/s]
# Downloading (…)l-00002-of-00002.bin:  66% 1.24G/1.87G [00:02<00:01, 366MB/s]
# Downloading (…)l-00002-of-00002.bin:  68% 1.28G/1.87G [00:02<00:01, 355MB/s]
# Downloading (…)l-00002-of-00002.bin:  71% 1.32G/1.87G [00:02<00:01, 358MB/s]
# Downloading (…)l-00002-of-00002.bin:  73% 1.36G/1.87G [00:03<00:01, 353MB/s]
# Downloading (…)l-00002-of-00002.bin:  75% 1.41G/1.87G [00:03<00:01, 356MB/s]
# Downloading (…)l-00002-of-00002.bin:  77% 1.45G/1.87G [00:03<00:01, 345MB/s]
# Downloading (…)l-00002-of-00002.bin:  80% 1.49G/1.87G [00:03<00:01, 342MB/s]
# Downloading (…)l-00002-of-00002.bin:  82% 1.53G/1.87G [00:03<00:01, 339MB/s]
# Downloading (…)l-00002-of-00002.bin:  84% 1.57G/1.87G [00:03<00:00, 335MB/s]
# Downloading (…)l-00002-of-00002.bin:  86% 1.61G/1.87G [00:03<00:00, 320MB/s]
# Downloading (…)l-00002-of-00002.bin:  89% 1.66G/1.87G [00:03<00:00, 314MB/s]
# Downloading (…)l-00002-of-00002.bin:  91% 1.70G/1.87G [00:04<00:00, 307MB/s]
# Downloading (…)l-00002-of-00002.bin:  93% 1.73G/1.87G [00:04<00:00, 303MB/s]
# Downloading (…)l-00002-of-00002.bin:  94% 1.76G/1.87G [00:04<00:00, 304MB/s]
# Downloading (…)l-00002-of-00002.bin:  96% 1.79G/1.87G [00:04<00:00, 296MB/s]
# Downloading (…)l-00002-of-00002.bin:  98% 1.82G/1.87G [00:04<00:00, 293MB/s]
# Downloading (…)l-00002-of-00002.bin: 100% 1.87G/1.87G [00:04<00:00, 395MB/s]
# Downloading shards: 100% 2/2 [00:33<00:00, 16.62s/it]
# Loading checkpoint shards: 100% 2/2 [00:09<00:00,  4.99s/it]
# Downloading (…)neration_config.json: 100% 116/116 [00:00<00:00, 772kB/s]
# model_lora : PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GPTNeoXForCausalLM(
#       (gpt_neox): GPTNeoXModel(
#         (embed_in): Embedding(30080, 4096)
#         (layers): ModuleList(
#           (0-27): 28 x GPTNeoXLayer(
#             (input_layernorm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#             (attention): GPTNeoXAttention(
#               (rotary_emb): RotaryEmbedding()
#               (query_key_value): Linear8bitLt(
#                 in_features=4096, out_features=12288, bias=True
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=12288, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (dense): Linear8bitLt(in_features=4096, out_features=4096, bias=True)
#             )
#             (mlp): GPTNeoXMLP(
#               (dense_h_to_4h): Linear8bitLt(in_features=4096, out_features=16384, bias=True)
#               (dense_4h_to_h): Linear8bitLt(in_features=16384, out_features=4096, bias=True)
#               (act): GELUActivation()
#             )
#           )
#         )
#         (final_layer_norm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#       )
#       (embed_out): Linear(in_features=4096, out_features=30080, bias=False)
#     )
#   )
# )
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-cbdc6929bee08787/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files: 100% 1/1 [00:00<00:00, 2176.60it/s]
# Extracting data files: 100% 1/1 [00:00<00:00,  1.76it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-cbdc6929bee08787/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
# 100% 2/2 [00:00<00:00, 382.34it/s]
# Map (num_proc=4):   0% 0/69 [00:00<?, ? examples/s]
#
#
#
#
#
# Map (num_proc=4):  23% 16/69 [00:00<00:00, 75.64 examples/s]
#
# Map (num_proc=4):   0% 0/8 [00:00<?, ? examples/s]
# Map (num_proc=4):  25% 2/8 [00:00<00:00, 12.66 examples/s]
#
#
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.2
# wandb: Run data is saved locally in /content/drive/MyDrive/Advertising_By_Personality/src/business_model/generation_lora/outputs/2023-05-10/06-48-34/wandb/run-20230510_065005-08w7b48v
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run batch2_step1000_lr5e-05
# wandb: ⭐️ View project at https://wandb.ai/textnet/Advertising_By_Personality
# wandb: 🚀 View run at https://wandb.ai/textnet/Advertising_By_Personality/runs/08w7b48v
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0% 0/1000 [00:00<?, ?it/s]You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 2.9027, 'learning_rate': 5e-06, 'epoch': 1.14}
# {'loss': 2.8689, 'learning_rate': 1e-05, 'epoch': 2.29}
# {'loss': 2.7601, 'learning_rate': 1.5e-05, 'epoch': 3.43}
# {'loss': 2.6421, 'learning_rate': 2e-05, 'epoch': 4.57}
# {'loss': 2.3545, 'learning_rate': 2.5e-05, 'epoch': 5.71}
# {'loss': 1.9667, 'learning_rate': 3e-05, 'epoch': 6.86}
# {'loss': 1.5648, 'learning_rate': 3.5e-05, 'epoch': 8.0}
# {'loss': 1.2291, 'learning_rate': 4e-05, 'epoch': 9.14}
# {'loss': 1.0209, 'learning_rate': 4.5e-05, 'epoch': 10.29}
# {'loss': 0.8123, 'learning_rate': 5e-05, 'epoch': 11.43}
#  10% 100/1000 [07:11<1:04:16,  4.29s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.6727, 'learning_rate': 4.9444444444444446e-05, 'epoch': 12.57}
# {'loss': 0.6192, 'learning_rate': 4.888888888888889e-05, 'epoch': 13.71}
# {'loss': 0.5268, 'learning_rate': 4.8333333333333334e-05, 'epoch': 14.86}
# {'loss': 0.4808, 'learning_rate': 4.7777777777777784e-05, 'epoch': 16.0}
# {'loss': 0.4266, 'learning_rate': 4.722222222222222e-05, 'epoch': 17.14}
# {'loss': 0.3945, 'learning_rate': 4.666666666666667e-05, 'epoch': 18.29}
# {'loss': 0.3427, 'learning_rate': 4.6111111111111115e-05, 'epoch': 19.43}
# {'loss': 0.3134, 'learning_rate': 4.555555555555556e-05, 'epoch': 20.57}
# {'loss': 0.2645, 'learning_rate': 4.5e-05, 'epoch': 21.71}
# {'loss': 0.237, 'learning_rate': 4.4444444444444447e-05, 'epoch': 22.86}
#  20% 200/1000 [14:39<57:30,  4.31s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.1954, 'learning_rate': 4.388888888888889e-05, 'epoch': 24.0}
# {'loss': 0.1673, 'learning_rate': 4.3333333333333334e-05, 'epoch': 25.14}
# {'loss': 0.1327, 'learning_rate': 4.277777777777778e-05, 'epoch': 26.29}
# {'loss': 0.117, 'learning_rate': 4.222222222222222e-05, 'epoch': 27.43}
# {'loss': 0.0924, 'learning_rate': 4.166666666666667e-05, 'epoch': 28.57}
# {'loss': 0.0746, 'learning_rate': 4.111111111111111e-05, 'epoch': 29.71}
# {'loss': 0.0601, 'learning_rate': 4.055555555555556e-05, 'epoch': 30.86}
# {'loss': 0.0516, 'learning_rate': 4e-05, 'epoch': 32.0}
# {'loss': 0.0432, 'learning_rate': 3.944444444444445e-05, 'epoch': 33.14}
# {'loss': 0.0359, 'learning_rate': 3.888888888888889e-05, 'epoch': 34.29}
#  30% 300/1000 [22:11<50:01,  4.29s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.0316, 'learning_rate': 3.8333333333333334e-05, 'epoch': 35.43}
# {'loss': 0.0292, 'learning_rate': 3.777777777777778e-05, 'epoch': 36.57}
# {'loss': 0.0269, 'learning_rate': 3.722222222222222e-05, 'epoch': 37.71}
# {'loss': 0.0257, 'learning_rate': 3.6666666666666666e-05, 'epoch': 38.86}
# {'loss': 0.0239, 'learning_rate': 3.611111111111111e-05, 'epoch': 40.0}
# {'loss': 0.0234, 'learning_rate': 3.555555555555556e-05, 'epoch': 41.14}
# {'loss': 0.0224, 'learning_rate': 3.5e-05, 'epoch': 42.29}
# {'loss': 0.0216, 'learning_rate': 3.444444444444445e-05, 'epoch': 43.43}
# {'loss': 0.0209, 'learning_rate': 3.388888888888889e-05, 'epoch': 44.57}
# {'loss': 0.0203, 'learning_rate': 3.3333333333333335e-05, 'epoch': 45.71}
#  40% 400/1000 [29:42<43:35,  4.36s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.0198, 'learning_rate': 3.277777777777778e-05, 'epoch': 46.86}
# {'loss': 0.0192, 'learning_rate': 3.222222222222223e-05, 'epoch': 48.0}
# {'loss': 0.0186, 'learning_rate': 3.1666666666666666e-05, 'epoch': 49.14}
# {'loss': 0.0183, 'learning_rate': 3.111111111111111e-05, 'epoch': 50.29}
# {'loss': 0.0179, 'learning_rate': 3.055555555555556e-05, 'epoch': 51.43}
# {'loss': 0.018, 'learning_rate': 3e-05, 'epoch': 52.57}
# {'loss': 0.0178, 'learning_rate': 2.9444444444444448e-05, 'epoch': 53.71}
# {'loss': 0.0181, 'learning_rate': 2.8888888888888888e-05, 'epoch': 54.86}
# {'loss': 0.0176, 'learning_rate': 2.8333333333333335e-05, 'epoch': 56.0}
# {'loss': 0.0173, 'learning_rate': 2.777777777777778e-05, 'epoch': 57.14}
#  50% 500/1000 [37:18<35:30,  4.26s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.0166, 'learning_rate': 2.7222222222222223e-05, 'epoch': 58.29}
# {'loss': 0.0168, 'learning_rate': 2.6666666666666667e-05, 'epoch': 59.43}
# {'loss': 0.017, 'learning_rate': 2.6111111111111114e-05, 'epoch': 60.57}
# {'loss': 0.0163, 'learning_rate': 2.5555555555555554e-05, 'epoch': 61.71}
# {'loss': 0.0166, 'learning_rate': 2.5e-05, 'epoch': 62.86}
# {'loss': 0.0164, 'learning_rate': 2.4444444444444445e-05, 'epoch': 64.0}
# {'loss': 0.0164, 'learning_rate': 2.3888888888888892e-05, 'epoch': 65.14}
# {'loss': 0.0159, 'learning_rate': 2.3333333333333336e-05, 'epoch': 66.29}
# {'loss': 0.0162, 'learning_rate': 2.277777777777778e-05, 'epoch': 67.43}
# {'loss': 0.016, 'learning_rate': 2.2222222222222223e-05, 'epoch': 68.57}
#  60% 600/1000 [44:53<28:40,  4.30s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.0157, 'learning_rate': 2.1666666666666667e-05, 'epoch': 69.71}
# {'loss': 0.0155, 'learning_rate': 2.111111111111111e-05, 'epoch': 70.86}
# {'loss': 0.0155, 'learning_rate': 2.0555555555555555e-05, 'epoch': 72.0}
# {'loss': 0.0152, 'learning_rate': 2e-05, 'epoch': 73.14}
# {'loss': 0.0151, 'learning_rate': 1.9444444444444445e-05, 'epoch': 74.29}
# {'loss': 0.0149, 'learning_rate': 1.888888888888889e-05, 'epoch': 75.43}
# {'loss': 0.0153, 'learning_rate': 1.8333333333333333e-05, 'epoch': 76.57}
# {'loss': 0.0149, 'learning_rate': 1.777777777777778e-05, 'epoch': 77.71}
# {'loss': 0.0148, 'learning_rate': 1.7222222222222224e-05, 'epoch': 78.86}
# {'loss': 0.0148, 'learning_rate': 1.6666666666666667e-05, 'epoch': 80.0}
#  70% 700/1000 [52:26<21:10,  4.23s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.0149, 'learning_rate': 1.6111111111111115e-05, 'epoch': 81.14}
# {'loss': 0.0146, 'learning_rate': 1.5555555555555555e-05, 'epoch': 82.29}
# {'loss': 0.0146, 'learning_rate': 1.5e-05, 'epoch': 83.43}
# {'loss': 0.0145, 'learning_rate': 1.4444444444444444e-05, 'epoch': 84.57}
# {'loss': 0.0145, 'learning_rate': 1.388888888888889e-05, 'epoch': 85.71}
# {'loss': 0.0142, 'learning_rate': 1.3333333333333333e-05, 'epoch': 86.86}
# {'loss': 0.0144, 'learning_rate': 1.2777777777777777e-05, 'epoch': 88.0}
# {'loss': 0.014, 'learning_rate': 1.2222222222222222e-05, 'epoch': 89.14}
# {'loss': 0.0142, 'learning_rate': 1.1666666666666668e-05, 'epoch': 90.29}
# {'loss': 0.014, 'learning_rate': 1.1111111111111112e-05, 'epoch': 91.43}
#  80% 800/1000 [59:57<14:19,  4.30s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.0142, 'learning_rate': 1.0555555555555555e-05, 'epoch': 92.57}
# {'loss': 0.0141, 'learning_rate': 1e-05, 'epoch': 93.71}
# {'loss': 0.0142, 'learning_rate': 9.444444444444445e-06, 'epoch': 94.86}
# {'loss': 0.0139, 'learning_rate': 8.88888888888889e-06, 'epoch': 96.0}
# {'loss': 0.0136, 'learning_rate': 8.333333333333334e-06, 'epoch': 97.14}
# {'loss': 0.0137, 'learning_rate': 7.777777777777777e-06, 'epoch': 98.29}
# {'loss': 0.0137, 'learning_rate': 7.222222222222222e-06, 'epoch': 99.43}
# {'loss': 0.0136, 'learning_rate': 6.666666666666667e-06, 'epoch': 100.57}
# {'loss': 0.0136, 'learning_rate': 6.111111111111111e-06, 'epoch': 101.71}
# {'loss': 0.0136, 'learning_rate': 5.555555555555556e-06, 'epoch': 102.86}
#  90% 900/1000 [1:07:30<07:15,  4.36s/it]/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:318: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# {'loss': 0.0135, 'learning_rate': 5e-06, 'epoch': 104.0}
# {'loss': 0.0135, 'learning_rate': 4.444444444444445e-06, 'epoch': 105.14}
# {'loss': 0.0135, 'learning_rate': 3.888888888888889e-06, 'epoch': 106.29}
# {'loss': 0.0134, 'learning_rate': 3.3333333333333333e-06, 'epoch': 107.43}
# {'loss': 0.0133, 'learning_rate': 2.777777777777778e-06, 'epoch': 108.57}
# {'loss': 0.0132, 'learning_rate': 2.2222222222222225e-06, 'epoch': 109.71}
# {'loss': 0.0134, 'learning_rate': 1.6666666666666667e-06, 'epoch': 110.86}
# {'loss': 0.0133, 'learning_rate': 1.1111111111111112e-06, 'epoch': 112.0}
# {'loss': 0.0132, 'learning_rate': 5.555555555555556e-07, 'epoch': 113.14}
# {'loss': 0.0131, 'learning_rate': 0.0, 'epoch': 114.29}
# {'train_runtime': 4527.1997, 'train_samples_per_second': 1.767, 'train_steps_per_second': 0.221, 'train_loss': 0.26530116444826124, 'epoch': 114.29}
# 100% 1000/1000 [1:15:27<00:00,  4.53s/it]
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:                    train/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:              train/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:            train/learning_rate ▂▃▅▇███▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                     train/loss ██▆▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               train/total_flos ▁
# wandb:               train/train_loss ▁
# wandb:            train/train_runtime ▁
# wandb: train/train_samples_per_second ▁
# wandb:   train/train_steps_per_second ▁
# wandb:
# wandb: Run summary:
# wandb:                    train/epoch 114.29
# wandb:              train/global_step 1000
# wandb:            train/learning_rate 0.0
# wandb:                     train/loss 0.0131
# wandb:               train/total_flos 1.1163226175756698e+17
# wandb:               train/train_loss 0.2653
# wandb:            train/train_runtime 4527.1997
# wandb: train/train_samples_per_second 1.767
# wandb:   train/train_steps_per_second 0.221
# wandb:
# wandb: 🚀 View run batch2_step1000_lr5e-05 at: https://wandb.ai/textnet/Advertising_By_Personality/runs/08w7b48v
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230510_065005-08w7b48v/logs

# %% [markdown]
# # Predict

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/business_model/generation')

# %%
# !python3 predict.py
# Out:
# /content/drive/MyDrive/Advertising_By_Personality/src/predict.py:12: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="./", config_name="config")
# /usr/local/lib/python3.9/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# 바꿀 문구 : 원문, 시즌 정보 :
# 화제의 갤럭시 노트10\ud83d\udcf1\댓글만 써도 100% 당첨+온라인체험존 ▶
# 바뀐 문구 : NT
# 2023-04-20 07:18:09.354594: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2023-04-20 07:18:10,186][numexpr.utils][INFO] - Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2023-04-20 07:18:10,187][numexpr.utils][INFO] - NumExpr defaulting to 8 threads.
# 댓글적립 3O% SSAP가능👌
#
# 온라인 체험존에서 성능 체크✔️ 댓글 남기기만 하면 1OO% 당첨🎁 실화예요? 응 실화예요🙆‍♀️ 참여만 해도 1분이면 되는데 놓치면 후회입니다💦
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : ST, 시즌 정보 :
# 굶기만 하는 다이어트는 이제 그만❌\건강하고 맛있는 다이어트 간식 GET하고 3,OOOP 받아가기✔️
# 바뀐 문구 : NF
# 프로다이어터들이 주목하는 꿀템🍯
#
# 식사대용 다이어트 간식 GET할 찬스⭐지금 받으러가요👉3천P 적립은 덤이에요
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : 원문, 시즌 정보 :
# 사용하신 포인트 돌려드립니다.\오늘 마감! 페이백 신청하러 가기▶
# 바뀐 문구 : NF
# 포인트 돌려준다고? 실화?
#
# 페이백 신청하러 가즈앗🙌
# 오늘까지니까 서두르세요😉
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : NF, 시즌 정보 :
# 아니 진짜 이래도 되는거야?!🔥\모르고 있었던 분들은 인생의 절반 손해본 겁니다😎 매일 최저가! [CJmall 어메이징 세일위크 2탄]에서 득템각⭐
# 바뀐 문구 : 원문
# CJmall 어메이징 세일위크 2탄 오픈!
#
# 매일 최저가 도전! 해피한 특가! 지금 바로 득템하세요
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : ST, 시즌 정보 :
# 꽝 없는 당첨 기회 도착★\주사위 던지고 발뮤다 공기청정기 득템♬\지금 바로 행운 잡으러 컴컴~!
# 바뀐 문구 : NF
# 의미 없는 것들만 골라 골랐어요🎲
#
# 당신께만 알려드리는 숨은 포인트👄 발뮤다 공기청정기 당첨 비법! 주사위 던지고 1OO% 당첨 선물 받아가세요!
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : ST, 시즌 정보 : 새해
# 고객님의 신년 운세 도착!\CJmall앱에서 공짜로 운세 확인✔️\행운 선물도 응모하고 새해 福 받으세요♥
# 바뀐 문구 : NT
# CJmall에서 새해 복 많이 받으세요🙇‍♀️
#
# 새해 운세 확인하면 푸짐한 경품 드려요🎁 앱에서 간편하게 응모하고 행운 선물 GET하세요✔️
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : 원문, 시즌 정보 : 겨울맞이
# 아직 구매하시지 않으셨나요?\방문만 해도 기프티콘 100% 증정
# 바뀐 문구 : SF
# 올맞이 쇼핑은 너로 정했다!
#
# 점점 추워지는 날씨에 지쳤다면 오시라고! 방문만 해도 기프티콘 무조건 드림!
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : ST, 시즌 정보 : 설연휴
# 설날은 [더플레이스 쿠폰]♬\다운받은 쿠폰 확인하고 더플레이스 가자!
# 바뀐 문구 : SF
# 설연휴엔 더플레이스와 함께~
#
# 모던한 분위기의 가족 모임 장소로 PICK❗
# 미식가라면 설날엔 이탈리안 감성이 돋보이는 마르게리따 맛보러 GO~
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : 원문, 시즌 정보 : 설연휴
# CJmall 설맞이 혜택받쥐\2020년 무료 신년운세 + 식품 10% 적립
# 바뀐 문구 : NT
# 무료채팅+식품 1O% 적립 실화?
#
# CJmall 설맞이 혜택 폭격✨ 당장 잡으러 가자! 무.료.로 신년 운세도 보고💡 포인트도 받고! 일석이조 찬스✨ 절대 놓치지 말자궁!
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : 원문, 시즌 정보 : 크리스마스
# \ud83c\udf84크리스마스 선물 쏩니다!\ud83c\udf84\2021년 운세만 보면 경품 100% 당첨!\ud83c\udf85\BESPOKE 큐브 냉장고도 받아가세요!
# 바뀐 문구 : NF
# 미리🎅: 호호호 미리크리스마스!
#
# [운세도ONE]님! 선물 무.조.건 당첨되는 경품을 받아가세요🎅🏻포인트에 큐브 냉장고 득템 찬스까지❣️
# ----------------------------------------------------------------------------------------------------
