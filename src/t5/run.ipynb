# %% [markdown]
# # Install

# %%
# !pip3 install hydra-core

# %%
# !pip3 install transformers

# %%
# !pip3 install datasets

# %%
# !pip3 install wandb

# %%
# !pip3 install pshmodule

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Run

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/t5/')

# %%
# !python3 train.py

# %% [markdown]
# # Predict

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/t5/')

# %%
# !python3 predict.py
# Out:
# /content/drive/MyDrive/Advertising_By_Personality/src/t5/predict.py:12: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="./", config_name="config")
# /usr/local/lib/python3.9/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# 바꿀 문구 : NT, 시즌 정보 :
# 당신은 덧셈 천재입니까?\\덧셈 게임 참여 시 💰31만 포인트가 [TAG1]님 주머니로 쏘-옥
# 바뀐 문구 : SF
# 2023-04-27 02:10:25.046337: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2023-04-27 02:10:25,859][numexpr.utils][INFO] - Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2023-04-27 02:10:25,861][numexpr.utils][INFO] - NumExpr defaulting to 8 threads.
# 천재들의 집합
#
# 덧셈 게임만 하면 1만P 획득♥️
# TAG1님을 위한 덧셈 게임 GO! 지금 참여하면 1만P 당첨 확률 UP!
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : ST, 시즌 정보 : 가을맞이
# 10월이니까 1OOO포인트♬\\브랜드별 할인 받고 1천P 적립까지 더!\알뜰하게 가을 옷 준비하려면 터치▶
# 바뀐 문구 : SF
# 가을맞이 BEST♥
#
# 브랜드별 할인+1천P 적립까지 GET할 수 있는 10월 혜택 확인하기!
# 지금 바로 CLICK하면 OPEN!
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : NF, 시즌 정보 : 신학기
# 우리 아이 성적도 자신감도 홈런⚾\\그 유명한 초등학습 1위 [홈런]\새학기를 맞아 무료 체험을 제공해요❣️ 역사 연대표와 포인트도 드리니까 부담없이 신청하세요😍
# 바뀐 문구 : NT
# ONE⚡
#
# 새학기 학습 1위 홈런이 준비한 무료 체험 기회💕
# 역사 연대표 & 포인트 증정
# CJ ONE 365일 매일 1개 이상 사용 시 포인트 추가 증정!
# BUTTORY [홈런] 초등학습 무료 체험 신청하러 GOGO
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : NT, 시즌 정보 : 어버이날
# 이번 어버이날 선물은 너로 정했다🎁\\지금 부모님 선물 구매하시면 2,OOOP를 사은품으로 드립니다💰 선물 사고 선물 받고🎵 꿩 먹고 알 먹고💗
# 바뀐 문구 : ST
# ART★ 어버이날 선물 GET하기 CLICK!
#
# 부모님 선물 구매하면 2,OOOP 증정 START! 지금 바로 GET하러 GOGO! [기프트카드] 구매 시 2천P 증정! ▶
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : ST, 시즌 정보 :
# 7일 뒤면 사라지는 쿠폰...❗\\7/일/뒤 혜택 종료!! 지금 앱에 접속해서 미사용 쿠폰 체크✔️체크✔️
# 바뀐 문구 : NF
# CJONE 앱👀
#
# 고객님을 위해 준비했어요🔊 미사용 쿠폰 체크해 주실거죠?(~7/일)
# [쿠폰] 사용 후 7일 뒤 혜택 종료 알림 보내드릴게요
# GOGOGO! 잊지 말고 사용하세요
# ANDER: 안녕하세요🔔️CLICK!
# ----------------------------------------------------------------------------------------------------
