# %% [markdown]
# # Install

# %%
# !pip3 install hydra-core

# %%
# !pip3 install transformers

# %%
# !pip3 install datasets

# %%
# !pip3 install wandb

# %%
# !pip3 install pshmodule

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Run

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/')

# %%
# !python3 train.py

# %% [markdown]
# # Predict

# %%
import os
os.chdir('drive/MyDrive/Advertising_By_Personality/src/')

# %%
# !python3 predict.py
# Out:
# /content/drive/MyDrive/Advertising_By_Personality/src/predict.py:12: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="./", config_name="config")
# /usr/local/lib/python3.9/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# 바꿀 문구 : NT, 시즌 정보 :
# 당신은 덧셈 천재입니까?\\덧셈 게임 참여 시 💰31만 포인트가 [TAG1]님 주머니로 쏘-옥
# 바뀐 문구 : SF
# 2023-04-14 05:20:30.307395: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2023-04-14 05:20:31,136][numexpr.utils][INFO] - Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2023-04-14 05:20:31,137][numexpr.utils][INFO] - NumExpr defaulting to 8 threads.
# 덧TAG1님 덧셈 실력을 뽐낼 시간
#
# 덧셈에 자신있는 고객님들 모여라~
# 지금 게임 참여하면 31만P의 행운이 팡팡!
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : ST, 시즌 정보 : 가을맞이
# 10월이니까 1OOO포인트♬\\브랜드별 할인 받고 1천P 적립까지 더!\알뜰하게 가을 옷 준비하려면 터치▶
# 바뀐 문구 : SF
# 가을바람 불어오면 기분도 UP!
#
# 10월 올리브영데이엔 브랜드별 할인 받고 1,OOOP 적립까지 GET
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : NF, 시즌 정보 : 신학기
# 우리 아이 성적도 자신감도 홈런⚾\\그 유명한 초등학습 1위 [홈런]\새학기를 맞아 무료 체험을 제공해요❣️ 역사 연대표와 포인트도 드리니까 부담없이 신청하세요😍
# 바뀐 문구 : NT
# 새학기가 돌아왔어요🎁
#
# 지금 홈런 무료체험 신청 시 역사 연대표+2,OOOP 증정💰 성적도 홈런 치고 싶다면? 지금 바로 신청하세요▶
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : NT, 시즌 정보 : 어버이날
# 이번 어버이날 선물은 너로 정했다🎁\\지금 부모님 선물 구매하시면 2,OOOP를 사은품으로 드립니다💰 선물 사고 선물 받고🎵 꿩 먹고 알 먹고💗
# 바뀐 문구 : ST
# 어 선물 사고 2,OOOP 받고
#
# 부모님 선물 사러 가기☞
# ----------------------------------------------------------------------------------------------------
# 바꿀 문구 : ST, 시즌 정보 :
# 7일 뒤면 사라지는 쿠폰...❗\\7/일/뒤 혜택 종료!! 지금 앱에 접속해서 미사용 쿠폰 체크✔️체크✔️
# 바뀐 문구 : NF
# 쿠폰:나 왔는데..잊지말고 사용해야지💦
#
# 고객님을 기다렸는데 깜빡하신 거 아니죠?(오열) 쿠폰 사라지기 전에 미사용 쿠폰 체크 GOGO
# ----------------------------------------------------------------------------------------------------
